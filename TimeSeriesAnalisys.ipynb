# %% [markdown]
# Добрый день, уважаемые читатели.

# %% [markdown]
# В сегодняшней статье, я попытаюсь описать процесс анализа временных рядов с помощью python и модуля <a href="http://statsmodels.sourceforge.net/stable/index.html">statsmodels</a>. Данный модуль предоставляет широкий набор средств и методов для проведения статистического анализа и эконометрики.

# %% [markdown]
# Для примера взяты реальные данные по товарообороту одного из складских комплексов Подмосковья. Приблизительный список шагов для анализа можно посмотреть <a href="">здесь</a>.

# %% [markdown]
# #### Загрузка и предварительная обработка данных

# %% [markdown]
# Для начала загрузим данные и посмотрим на них:

# %%
from pandas import read_csv, DataFrame
import statsmodels.api as sm
from statsmodels.iolib.table import SimpleTable
from sklearn.metrics import r2_score

# %%
dataset = read_csv('tovar_moving.csv',';', index_col=['date_oper'], parse_dates=['date_oper'], dayfirst=True)
dataset.head()
# Out:
#             Otgruzka  priemka
# date_oper
# 2009-09-01    179667   276712
# 2009-09-02    177670   164999
# 2009-09-03    152112   189181
# 2009-09-04    142938   254581
# 2009-09-05    130741   192486

# %% [markdown]
# Итак, как можно заметить функция <a href='http://pandas.pydata.org/pandas-docs/stable/generated/pandas.io.parsers.read_csv.html?highlight=read_csv#pandas.io.parsers.read_csv'>read_csv()</a>, в данном случем помимо указания параметров, которые задают используемые колонки и индекс, можно заметить еще 3 параметра для работы с датой. Остановимся на них поподробнее.

# %% [markdown]
# <b>parse_dates</b> задает имена столбцов, которые будут преобразованы в тип <i>DateTime</i>. Стоит отметить, что если в данном столбце будут пустые значения парсинг не удастся и вернется столбец типа <i>object</i>. Чтобы этого избежать надо добавить параметр <i><b>keep_default_na</b>=False</i>.

# %% [markdown]
# Заключительный параметр <b>dayfirst</b> указывает функции парсинга, что первое в строке первым идет день, а не наоборот. Если не задать этот параметр, то функция может не правильно преобразовывать даты и путать месяц и день местами. Например <i>01.02.2013</i> будет преобразовано в <i>02-01-2013</i>, что будет неправильно.

# %% [markdown]
# Выделим в отдельную серию временной ряд со значениями отгрузкок:

# %%
otg = dataset.Otgruzka
otg.head()
# Out:
# date_oper
# 2009-09-01    179667
# 2009-09-02    177670
# 2009-09-03    152112
# 2009-09-04    142938
# 2009-09-05    130741
# Name: Otgruzka, dtype: int64

# %% [markdown]
# Итак у нас теперь есть временной ряд и можно перейти к его анализу.

# %% [markdown]
# #### Анализ временного ряда

# %% [markdown]
# Для начала давайте посмортим график нашего ряда:

# %%
otg.plot(figsize=(12,6))

# %% [markdown]
# Из графика видно, что наш ряд имеет небольшое кол-во выбросов, которые влияют на разброс. Кроме того анализировать отгрузки за каждый день не совсем верно, т.к., например, в конце или начале недели будут дни в которые товара отгружается значительно больше, нежели в остальные. Поэтому есть смысл перейти к месячному интервалу и среднему значению отгрузок на нем, это избавит нас от выбросов и уменьшит колебания нашего ряда. В <b>pandas</b> для этого есть удобная функция <a href='http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.resample.html?highlight=resample#pandas.DataFrame.resample'>resample()</a>, в качестве параметров ей передается период округления и аггрегатная функция:

# %%
otg = otg.resample('M', how='mean')
otg.plot(figsize=(12,6))

# %% [markdown]
# Как можно заметить, новый график не имеет ярких выбросов и имеет ярко выраженный тренд. Из это можно сделать вывод о том, что ряд не является стационарным<sup><a href="#1">[1]</a></sup>.

# %% [markdown]
# Давайте посмотрим на характеристики данного ряда:

# %%
itog = otg.describe()
otg.hist()
itog
# Out:
# count        52.000000
# mean     272488.335910
# std      113981.152384
# min       78110.931034
# 25%      188913.516129
# 50%      284132.435484
# 75%      357859.823563
# max      498964.300000
# dtype: float64

# %% [markdown]
# Как можно заметить из характеристик и гистограммы, ряд у нас более менее однородный и имеет относительно небольшой разброс о чем свидетельствует <a href='http://ru.wikipedia.org/wiki/%D0%9A%D0%BE%D1%8D%D1%84%D1%84%D0%B8%D1%86%D0%B8%D0%B5%D0%BD%D1%82_%D0%B2%D0%B0%D1%80%D0%B8%D0%B0%D1%86%D0%B8%D0%B8#.D0.9E.D1.82.D0.BD.D0.BE.D1.81.D0.B8.D1.82.D0.B5.D0.BB.D1.8C.D0.BD.D1.8B.D0.B5_.D0.BF.D0.BE.D0.BA.D0.B0.D0.B7.D0.B0.D1.82.D0.B5.D0.BB.D0.B8'>коэффициент вариации</a>: $V = \frac {\sigma}{\bar{x}} $, где $\sigma$ - <a href="http://ru.wikipedia.org/wiki/%D0%A1%D1%80%D0%B5%D0%B4%D0%BD%D0%B5%D0%BA%D0%B2%D0%B0%D0%B4%D1%80%D0%B0%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%BE%D0%B5_%D0%BE%D1%82%D0%BA%D0%BB%D0%BE%D0%BD%D0%B5%D0%BD%D0%B8%D0%B5">cреднеквадратическое отклонение</a>, $\bar{x}$ - среднее арифметическое выборки. В нашем случае он равен:

# %%
print 'V = %f' % (itog['std']/itog['mean'])
# Out:
# V = 0.437022

# %% [markdown]
# Проведем <a href='http://ru.wikipedia.org/wiki/%D0%A2%D0%B5%D1%81%D1%82_%D0%A5%D0%B0%D1%80%D0%BA%D0%B8_%E2%80%94_%D0%91%D0%B5%D1%80%D0%B0'>тест Харки — Бера</a> для определения номарльности распределения, чтобы подтвердить предположение об однородности. Для этого в существует функция <a href='http://statsmodels.sourceforge.net/stable/generated/statsmodels.stats.stattools.jarque_bera.html#statsmodels.stats.stattools.jarque_bera'>jarque_bera()</a>, которая возвращает значения данной статистики:

# %%
row =  [u'JB', u'p-value', u'skew', u'kurtosis']
jb_test = sm.stats.stattools.jarque_bera(otg)
a = np.vstack([jb_test])
itog = SimpleTable(a, row)
print itog
# Out:
# ...
#       JB         p-value          skew        kurtosis
# --------------------------------------------------------
# 1.88975643712 0.388726907743 0.063340407204 2.0747177458
# --------------------------------------------------------

# %% [markdown]
# Значение данной статистика свидетельствует о том, нулевая гипотеза о нормальности распределения отвергается с малой вероятностью (<i>probably > 0.05</i>), и, следовательно, наш ряд имеет нормального распределения.

# %% [markdown]
# Функция <a href='http://statsmodels.sourceforge.net/stable/generated/statsmodels.iolib.table.SimpleTable.html'>SimpleTable()</a> служит для оформления вывода. В нашем случае на вход ей подается массив значений (размерность не больше 2) и список с названиями столбцов или строк.

# %% [markdown]
# Многие методы и модели основаны на предположениях о стационарности ряда, но как было замечено ранее наш ряд таковым скорее всего не является. Поэтому для проверки проверки стационарности давайте проведем <a href='http://ru.wikipedia.org/wiki/%D0%A2%D0%B5%D1%81%D1%82_%D0%94%D0%B8%D0%BA%D0%B8_%E2%80%94_%D0%A4%D1%83%D0%BB%D0%BB%D0%B5%D1%80%D0%B0'>обобщенный тест Дикки-Фуллера</a> на наличие единичных корней. Для этого в модуле <b>statsmodels</b> есть функция <a href="http://statsmodels.sourceforge.net/stable/generated/statsmodels.tsa.stattools.adfuller.html#statsmodels.tsa.stattools.adfuller">adfuller()</a>:

# %%
test = sm.tsa.adfuller(otg)
print 'adf: ', test[0] 
print 'p-value: ', test[1]
print'Critical values: ', test[4]
if test[0]> test[4]['5%']: 
    print 'есть единичные корни, ряд не стационарен'
else:
    print 'единичных корней нет, ряд стационарен'
# Out:
# adf:  -0.562168220124
# p-value:  0.879303395804
# Critical values:  {'5%': -2.9253381054294332, '1%': -3.5778480370438146, '10%': -2.6007735310095064}
# есть единичные корни, ряд не стационарен

# %% [markdown]
# Проведенный тест подтвердил предположения о не стационарности ряда. Во многих случаях взятие <a href='http://computerscinece.ru/%d0%b3%d0%bb%d0%be%d1%81%d1%81%d0%b0%d1%80%d0%b8%d0%b9/psur'>разности рядов</a> позволяет это сделать.

# %% [markdown]
# Если, например, первые разности ряда стационарны, то он называется <i>интегрированным рядом первого порядка</i>.

# %% [markdown]
# Итак, давайте определим <i>порядок интегрированного ряда</i> для нашего ряда:

# %%
otg1diff = otg.diff(periods=1).dropna()

# %% [markdown]
# В коде выше функция <a href='http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.diff.html?highlight=diff#pandas.DataFrame.diff'>diff()</a> вычисляет разность исходного ряда с рядом с заданным смещением периода. Период смещения передается как параметр <i>period</i>. Т.к. в разности первое значение получиться неопределенным, то нам надо избавиться от него для этого и используется метод <a href=''>dropna()</a>.

# %% [markdown]
# Проверим получившийся ряд на стационарность:

# %%
test = sm.tsa.adfuller(otg1diff)
print 'adf: ', test[0]
print 'p-value: ', test[1]
print'Critical values: ', test[4]
if test[0]> test[4]['5%']: 
    print 'есть единичные корни, ряд не стационарен'
else:
    print 'единичных корней нет, ряд стационарен'
# Out:
# adf:  -10.0413506856
# p-value:  1.49339297195e-17
# Critical values:  {'5%': -2.9253381054294332, '1%': -3.5778480370438146, '10%': -2.6007735310095064}
# единичных корней нет, ряд стационарен

# %% [markdown]
# Как видно из кода выше получившийся ряд первых разностей приблизился к стационарному. Для полной уверенности разобъем его на несколько промежутков и  убедимся мат. ожидания на разных интервалах:

# %%
m = otg1diff.index[len(otg1diff.index)/2+1]
r1 = sm.stats.DescrStatsW(otg1diff[m:])
r2 = sm.stats.DescrStatsW(otg1diff[:m])
print 'p-value: ', sm.stats.CompareMeans(r1,r2).ttest_ind()[1]
# Out:
# p-value:  0.757673817955

# %% [markdown]
# Высокое <i>p-value</i> дает нам возможность утверждать, что нулевая гипотеза о равенстве средних верна, что свидетельствует о стационарности ряда. Осталось убедиться в отсутствии тренда для этого построим график нашего нового ряда:

# %%
otg1diff.plot(figsize=(12,6))

# %% [markdown]
# Тренд действительно отсутствует, таким образом ряд первых разностей является стационарным, а наш исходный ряд - <i>интегрированным рядом первого порядка</i>.

# %% [markdown]
# #### Построение модели временного ряда

# %% [markdown]
# Для моделирования будем использовать модель <a href='http://ru.wikipedia.org/wiki/ARMA'>ARMA</a>, построенную для ряда первых разностей.

# %% [markdown]
# Итак, чтобы построить модель нам нужно знать ее порядок, состоящий из 2-х параметров:
# <ol>
# <li><b>p</b> - порядок компоненты <a href='http://ru.wikipedia.org/wiki/%D0%90%D0%B2%D1%82%D0%BE%D1%80%D0%B5%D0%B3%D1%80%D0%B5%D1%81%D1%81%D0%B8%D0%BE%D0%BD%D0%BD%D0%B0%D1%8F_%D0%BC%D0%BE%D0%B4%D0%B5%D0%BB%D1%8C'>AR</a></li>
# <li><b>d</b> - порядок интегрированного ряда
# <li><b>q</b> - порядок компонетны <a href='http://ru.wikipedia.org/wiki/%D0%9C%D0%BE%D0%B4%D0%B5%D0%BB%D1%8C_%D1%81%D0%BA%D0%BE%D0%BB%D1%8C%D0%B7%D1%8F%D1%89%D0%B5%D0%B3%D0%BE_%D1%81%D1%80%D0%B5%D0%B4%D0%BD%D0%B5%D0%B3%D0%BE'>MA</a></li>
# </ol>

# %% [markdown]
# Параметр <b>d</b> есть и он равет 1, осталось определить <b>p</b> и <b>q</b>. Для их определения нам надо изучить <a href='http://ru.wikipedia.org/wiki/%D0%90%D0%B2%D1%82%D0%BE%D0%BA%D0%BE%D1%80%D1%80%D0%B5%D0%BB%D1%8F%D1%86%D0%B8%D0%BE%D0%BD%D0%BD%D0%B0%D1%8F_%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D1%8F'>авторкорреляционную(ACF)</a> и <a href=''>частично автокорреляционную(PACF)</a> функции исходного ряда.

# %% [markdown]
# <b>ACF</b> поможет нам определить <b>q</b>, т. к. по ее коррелограмме можно определить количество автокорреляционных коэффициентов сильно отличных от 0 в модели <b>MA</b>

# %% [markdown]
# <b>PACF</b> поможет нам определить <b>p</b>, т. к. по ее коррелограмме можно определить максимальный номер коэффициента сильно отличный от 0 в модели <b>AR</b>.

# %% [markdown]
# Чтобы построить соответствующие коррелограммы, в пакете </i>statsmodels</i> имеются следующие функции: <a href='http://statsmodels.sourceforge.net/stable/generated/statsmodels.graphics.tsaplots.plot_acf.html'>plot_acf()</a> и <a href='http://statsmodels.sourceforge.net/stable/generated/statsmodels.graphics.tsaplots.plot_pacf.html'>plot_pacf()</a>. Они выводят графики <i>ACF</i> и <i>PACF</i>, у которых по оси X откладываются номера лагов, а по оси Y значения соответствующих функций. Нужно отметить, что количество лагов в функциях и определяет число значимых коэффициентов. Итак, наши функции выглядят так:

# %%
o = otg
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(otg.values.squeeze(), lags=30, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(otg, lags=30, ax=ax2)

# %% [markdown]
# После изучения коррелограммы <i>PACF</i> можно сделать вывод, что <b>p = 1</b> , т.к. на ней только 1 лаг сильно отличнен от нуля. По коррелограмме <i>ACF</i> можно увидеть, что <b>q = 3</b>, т.к. после лага 3 значении функций резко падают.

# %% [markdown]
# Итак, когда известны все параметры можно построить модель, но для ее построения мы возмем не все данные, а только часть. Данные из части не попавших в модель мы оставим для проверки точности прогноза нашей модели:

# %%
src_data_model = otg[:'2013-05']
model = sm.tsa.ARIMA(src_data_model, order=(1,1,3)).fit(trend='nc')

# %% [markdown]
# Параметр <i>trend</i> отвечает за наличие константы в моделе. Выведем информацаю по получившейся модели:

# %%
print model.summary()
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                    D.y   No. Observations:                   44
# Model:                 ARIMA(1, 1, 3)   Log Likelihood                -528.813
# Method:                       css-mle   S.D. of innovations          39663.713
# Date:                Mon, 23 Dec 2013   AIC                           1067.626
# Time:                        17:31:52   BIC                           1076.547
# Sample:                    10-31-2009   HQIC                          1070.934
#                          - 05-31-2013
# ...
#                  coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# ar.L1.D.y      0.0576      0.255      0.226      0.823        -0.443     0.558
# ma.L1.D.y     -0.1627      0.211     -0.772      0.445        -0.576     0.250
# ma.L2.D.y      0.2018      0.203      0.995      0.326        -0.196     0.599
# ...

# %% [markdown]
# Как видно из данной информации в нашей модели есть 1 не значимый параметров, его можно убрать и заново провести тесты, но я пока не разобрался как это можно сделать, поэтому дальше мы будем оценивать данную модель.

# %% [markdown]
# #### Анализ и оценка модели

# %% [markdown]
# Проверим остатки данной модели на соответствие <a href='http://ru.wikipedia.org/wiki/%C1%E5%EB%FB%E9_%F8%F3%EC'>"белому шуму"</a>, а также проанализируем коррелограму остатков, так как это может нам помочь в определении важных для включения и прогнозирования элементов регрессии.

# %% [markdown]
# Итак первое, что мы сделаем это проведем <a href='http://ru.wikipedia.org/wiki/Q-%D1%82%D0%B5%D1%81%D1%82_%D0%9B%D1%8C%D1%8E%D0%BD%D0%B3%D0%B0_%E2%80%94_%D0%91%D0%BE%D0%BA%D1%81%D0%B0'>Q-тест Льюнга — Бокса</a> для проверки гипотезы о том, что остатки случайны, т. е. являются "белым шумом". Данный тест проводится на остатках модели <b>ARIMA</b>. Таким образом, нам надо сначала получить остатки модели и построить для них ACF, а затем к получившимся коэффициентам приметить тест. С помощью <i>statsmadels</i> это можно сделать так:

# %%
q_test = sm.tsa.stattools.acf(arma_model.resid, qstat=True) #свойство resid, хранит остатки модели 
                                                            #qstat=True, означает что применяем указынный тест к коэф-ам
print DataFrame({'Q-stat':q_test[1], 'p-value':q_test[2]})
# Out:
#        Q-stat   p-value
# 0    0.274894  0.600068
# 1    2.555858  0.278614
# 2    6.180889  0.103134
# 3    6.890425  0.141793
# 4    8.606507  0.125827
# 5   10.871531  0.092429
# 6   11.565677  0.115777
# 7   12.833321  0.117715
# 8   14.203075  0.115283
# 9   14.903887  0.135605
# 10  15.121634  0.176996
# 11  25.523422  0.012528
# 12  25.573296  0.019387
# 13  27.869919  0.014804
# 14  28.871868  0.016707
# 15  29.358910  0.021625
# 16  29.986953  0.026439
# 17  30.647479  0.031608
# 18  30.925636  0.041138
# 19  31.160644  0.053105
# 20  33.064902  0.045502
# 21  33.546859  0.054584
# 22  33.599196  0.071180
# 23  39.836888  0.022265
# 24  40.302115  0.027146
# 25  42.057988  0.024213
# 26  43.798141  0.021692
# 27  43.932911  0.028213
# 28  44.455531  0.033209
# 29  46.585769  0.027299
# 30  46.638408  0.035376
# 31  46.703893  0.045071
# 32  48.557129  0.039536
# 33  48.593012  0.050092
# 34  48.731408  0.061437
# 35  49.842967  0.062282
# 36  50.701022  0.066100
# ...

# %% [markdown]
# Значение данной статистики и p-values, свидетельствуют о том, что гипотеза о случайности остатков не отвергается, и скорее всего данный процесс предствляет "белый шум".

# %% [markdown]
# Теперь проведем <a href='http://ru.wikipedia.org/wiki/%D0%A2%D0%B5%D1%81%D1%82_%D0%91%D1%80%D0%BE%D0%B9%D1%88%D0%B0_%E2%80%94_%D0%9F%D0%B0%D0%B3%D0%B0%D0%BD%D0%B0'>Тест Бройша — Пагана</a> для тестирования <a href='http://ru.wikipedia.org/wiki/%D0%93%D0%B5%D1%82%D0%B5%D1%80%D0%BE%D1%81%D0%BA%D0%B5%D0%B4%D0%B0%D1%81%D1%82%D0%B8%D1%87%D0%BD%D0%BE%D1%81%D1%82%D1%8C'>гетероскедастичности</a> случайных ошибок регрессионной модели, т.е. другими словами проверем единство дисперсии на остатках:

# %%
print 'F-статистика: ', sm.stats.diagnostic.het_breushpagan(arma_model.resid, np.vstack(src_data_model.values)[1:])[2]
print 'p-value: ', sm.stats.diagnostic.het_breushpagan(arma_model.resid, np.vstack(src_data_model.values)[1:])[3]
# Out:
# F-статистика:  24.3766032934
# p-value:  1.24281983472e-05

# %% [markdown]
# В тесте выдвигается предположение о том, что ряд обладает постоянной дисперсией. Как показывает наше p-значение, мы не можем отвергуть эту теорию.

# %% [markdown]
# Из вышеприведенных тестов, можно сделать вывод о том, что остатки нашей модели соотвтетсвуют "белому шуму".

# %% [markdown]
# Теперь давайте проведем тест статистической значимости нашего уравнения с помощью <a href='http://ru.wikipedia.org/wiki/F-%D1%82%D0%B5%D1%81%D1%82'>F-критерия Фишера</a> и расчитаем коэффициент детерминации $R^2$, чтобы понять какой процент наблюдений описывает данная модель:

# %%
print 'R^2: %f' % r2_score(otg['2013-06':], model.predict('2013-05-31','2013-12-31',typ='levels', dynamic=True)[1:])
# Out:
# R^2: -0.498432

# %% [markdown]
# Коэффициент детерминации, показывает, что наша модель описывает 46% наблюдений, что вообщем-то не плохо.

# %% [markdown]
# #### Заключение

# %% [markdown]
# #### Ссылки

# %% [markdown]
# <ol>
# <li><a name="1">И.И. Елисеева. Эконометрика</a></li>
# <li></li>
# <li></li>
# </ol>
