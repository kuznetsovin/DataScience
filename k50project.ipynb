# %% [markdown]
# #### Описание данных

# %% [markdown]
# <table>
# 	<tr><th>№ пп.</th><th>Название поля</th><th>Описание</th></tr>
# 	<tr><td>1</td><td>id </td><td>порядковый номер строчки</td></tr>
# 	<tr><td>2</td><td>date</td><td>дата захода на сайт</td></tr>
# 	<tr><td>3</td><td>revenue </td><td>стоимость товаров в заказе</td></tr>
# 	<tr><td>4</td><td>url</td><td>URL, на который человек перешёл на наш сайт(без utm-разметки)</td></tr>
# 	<tr><td>5</td><td>urlWithoutQuery</td><td>url без параметров передаваемых через ?, ну т.е /books/tsvetaeva?lfrom=22 =&gt; /books/tsvetaeva</td></tr>
# 	<tr><td>6</td><td>model</td><td>модель товара в яндекс.маркете</td></tr>
# 	<tr><td>7</td><td>vendor</td><td>производитель (бренд) товара в яндекс.маркете</td></tr>
# 	<tr><td>8</td><td>yml_id</td><td>id товара в яндекс.маркете</td></tr>
# 	<tr><td>9</td><td>yml_cat_id</td><td>id категории в яндекс.маркете</td></tr>
# 	<tr><td>10</td><td>k50id</td><td>id-шник, через который мы понимаем через какое именно объявление и какой ключевик мы получили заказ</td></tr>
# 	<tr><td>11</td><td>visits</td><td>количество визитов на сайт с такими комбинациями факторов</td></tr>
# 	<tr><td>12</td><td>campaign</td><td>название рекламной кампании, через которую был осуществлён переход на сайт</td></tr>
# 	<tr><td>13</td><td>source</td><td>источник, с которого пользователь попал на сайт</td></tr>
# 	<tr><td>14</td><td>medium</td><td>тип трафика (рекламный, из органической выдачи, по ссылке из других сайтов)</td></tr>
# 	<tr><td>15</td><td>keyword</td><td>ключевой запрос, по которому осуществлён переход</td></tr>
# 	<tr><td>16</td><td>goal1Completions</td><td>какая-то цель из аналитикса</td></tr>
# 	<tr><td>17</td><td>landingPagePath</td><td>URL, на который человек перешёл на наш сайт(с utm-разметкой)</td></tr>
# 	<tr><td>18</td><td>transactions</td><td>количество транзаций по данной комбинации факторов</td></tr>
# </table>

# %%
from pandas import read_csv

# %%
a = read_csv('/Users/igorkuznetsov/Projects/DataScience/DataSets/k50projectDataset.csv';','
