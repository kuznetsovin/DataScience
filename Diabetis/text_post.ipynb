# %%
from pandas import read_csv, DataFrame
from sklearn import cross_validation, svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc
from pandas.tools.plotting import scatter_matrix
import pylab as pl
from sklearn import linear_model


data = read_csv('train.csv', header=None)

target = data[0]
train = data.drop(0, axis=1)

# %%
scatter_matrix(data, alpha=0.2)
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x11fad7290>,
#         <matplotlib.axes.AxesSubplot object at 0x120d73450>,
#         <matplotlib.axes.AxesSubplot object at 0x120d8d1d0>,
#         <matplotlib.axes.AxesSubplot object at 0x120d70f10>,
#         <matplotlib.axes.AxesSubplot object at 0x120dc60d0>,
#         <matplotlib.axes.AxesSubplot object at 0x1210e7390>,
#         <matplotlib.axes.AxesSubplot object at 0x120dcd050>,
#         <matplotlib.axes.AxesSubplot object at 0x12111d9d0>,
#         <matplotlib.axes.AxesSubplot object at 0x12103bd10>],
#        [<matplotlib.axes.AxesSubplot object at 0x121027a10>,
#         <matplotlib.axes.AxesSubplot object at 0x120f11310>,
#         <matplotlib.axes.AxesSubplot object at 0x120f31650>,
#         <matplotlib.axes.AxesSubplot object at 0x120f18ad0>,
#         <matplotlib.axes.AxesSubplot object at 0x120f8bc10>,
#         <matplotlib.axes.AxesSubplot object at 0x120fabf50>,
#         <matplotlib.axes.AxesSubplot object at 0x120f95ad0>,
#         <matplotlib.axes.AxesSubplot object at 0x120fe5550>,
#         <matplotlib.axes.AxesSubplot object at 0x121005890>],
#        [<matplotlib.axes.AxesSubplot object at 0x120feccd0>,
#         <matplotlib.axes.AxesSubplot object at 0x12109ad90>,
#         <matplotlib.axes.AxesSubplot object at 0x1210bcf90>,
#         <matplotlib.axes.AxesSubplot object at 0x1210a5c50>,
#         <matplotlib.axes.AxesSubplot object at 0x121175690>,
#         <matplotlib.axes.AxesSubplot object at 0x1211959d0>,
#         <matplotlib.axes.AxesSubplot object at 0x12117ddd0>,
#         <matplotlib.axes.AxesSubplot object at 0x121c06f90>,
#         <matplotlib.axes.AxesSubplot object at 0x121c2a310>],
#        [<matplotlib.axes.AxesSubplot object at 0x121c11e50>,
#         <matplotlib.axes.AxesSubplot object at 0x121c608d0>,
#         <matplotlib.axes.AxesSubplot object at 0x121c80c10>,
#         <matplotlib.axes.AxesSubplot object at 0x121c67ed0>,
#         <matplotlib.axes.AxesSubplot object at 0x121cb9210>,
#         <matplotlib.axes.AxesSubplot object at 0x121cdb550>,
#         <matplotlib.axes.AxesSubplot object at 0x121cc29d0>,
#         <matplotlib.axes.AxesSubplot object at 0x122810b10>,
#         <matplotlib.axes.AxesSubplot object at 0x122832e50>],
#        [<matplotlib.axes.AxesSubplot object at 0x12281a150>,
#         <matplotlib.axes.AxesSubplot object at 0x12286b450>,
#         <matplotlib.axes.AxesSubplot object at 0x12288b790>,
#         <matplotlib.axes.AxesSubplot object at 0x122871bd0>,
#         <matplotlib.axes.AxesSubplot object at 0x1228c1d50>,
#         <matplotlib.axes.AxesSubplot object at 0x1228e60d0>,
#         <matplotlib.axes.AxesSubplot object at 0x1228cb4d0>,
#         <matplotlib.axes.AxesSubplot object at 0x122e1a690>,
#         <matplotlib.axes.AxesSubplot object at 0x122e3b9d0>],
#        [<matplotlib.axes.AxesSubplot object at 0x122e22dd0>,
#         <matplotlib.axes.AxesSubplot object at 0x122e71f90>,
#         <matplotlib.axes.AxesSubplot object at 0x122e95310>,
#         <matplotlib.axes.AxesSubplot object at 0x122e7ce50>,
#         <matplotlib.axes.AxesSubplot object at 0x122eca8d0>,
#         <matplotlib.axes.AxesSubplot object at 0x122eebc10>,
#         <matplotlib.axes.AxesSubplot object at 0x122ed3ed0>,
#         <matplotlib.axes.AxesSubplot object at 0x123224210>,
#         <matplotlib.axes.AxesSubplot object at 0x123245550>],
#        [<matplotlib.axes.AxesSubplot object at 0x12322c9d0>,
#         <matplotlib.axes.AxesSubplot object at 0x12327bb10>,
#         <matplotlib.axes.AxesSubplot object at 0x12329be50>,
#         <matplotlib.axes.AxesSubplot object at 0x123286150>,
#         <matplotlib.axes.AxesSubplot object at 0x1232d5450>,
#         <matplotlib.axes.AxesSubplot object at 0x1232f6790>,
#         <matplotlib.axes.AxesSubplot object at 0x1232debd0>,
#         <matplotlib.axes.AxesSubplot object at 0x12372ad50>,
#         <matplotlib.axes.AxesSubplot object at 0x1237500d0>],
#        [<matplotlib.axes.AxesSubplot object at 0x1237374d0>,
#         <matplotlib.axes.AxesSubplot object at 0x123786690>,
#         <matplotlib.axes.AxesSubplot object at 0x1237a59d0>,
#         <matplotlib.axes.AxesSubplot object at 0x12378edd0>,
#         <matplotlib.axes.AxesSubplot object at 0x1237def90>,
#         <matplotlib.axes.AxesSubplot object at 0x1237ff310>,
#         <matplotlib.axes.AxesSubplot object at 0x1237e7e50>,
#         <matplotlib.axes.AxesSubplot object at 0x123b378d0>,
#         <matplotlib.axes.AxesSubplot object at 0x123b55c10>],
#        [<matplotlib.axes.AxesSubplot object at 0x123b3ded0>,
#         <matplotlib.axes.AxesSubplot object at 0x123b90210>,
#         <matplotlib.axes.AxesSubplot object at 0x123bb0550>,
#         <matplotlib.axes.AxesSubplot object at 0x123b989d0>,
#         <matplotlib.axes.AxesSubplot object at 0x123be7b10>,
#         <matplotlib.axes.AxesSubplot object at 0x124006e50>,
#         <matplotlib.axes.AxesSubplot object at 0x123bf1150>,
#         <matplotlib.axes.AxesSubplot object at 0x124041450>,
#         <matplotlib.axes.AxesSubplot object at 0x124061790>]], dtype=object)

# %%
kfold = 10
itog = DataFrame(index=xrange(kfold))

#Строим модели
model = linear_model.LinearRegression()
scores = cross_validation.cross_val_score(model, train, target, cv = kfold)
itog.insert(len(itog.columns),'LinearRegression',scores)

# %%
model = svm.SVC(kernel='linear')
scores = cross_validation.cross_val_score(model, train, target, cv = kfold)
itog.insert(len(itog.columns),'SVM Liner',scores)

# %%
model = svm.SVC(kernel='poly')
scores = cross_validation.cross_val_score(model, train, target, cv = kfold)
itog.insert(len(itog.columns),'SVM Poly',scores)

# %%
model = svm.SVC(kernel='rbf', gamma=0.7)
scores = cross_validation.cross_val_score(model, train, target, cv = kfold)
itog.insert(len(itog.columns),'SVM rbf',scores)

# %%
for n in range(5,15,4):   
    model = KNeighborsClassifier(n_neighbors = n)
    scores = cross_validation.cross_val_score(model, train, target, cv = kfold)
    FieldName = str(model)[:str(model).find('(')] + ' ' + str(model.n_neighbors)
    itog.insert(len(itog.columns), FieldName, scores)

# %%
model = BernoulliNB()
scores = cross_validation.cross_val_score(model, train, target, cv = kfold)
itog.insert(len(itog.columns),'BernulNaiveBaes',scores)

# %%
for n in range(20,81,30):
    model = RandomForestClassifier(n_estimators = n, max_features='log2')
    scores = cross_validation.cross_val_score(model, train, target, cv = kfold)
    FieldName = str(model)[:str(model).find('(')] + ' ' + str(model.n_estimators)
    itog.insert(len(itog.columns), FieldName, scores)

# %%
SumInfo = itog.describe().transpose()

# %%
SumInfo['mean'].plot(kind='bar', legend=False)

# %%
SumInfo['mean']
# Out:
# LinearRegression             0.220095
# SVM Liner                    0.769532
# SVM Poly                     0.743455
# SVM rbf                      0.739645
# KNeighborsClassifier 5       0.746292
# KNeighborsClassifier 9       0.742293
# KNeighborsClassifier 13      0.743524
# BernulNaiveBaes              0.722710
# RandomForestClassifier 20    0.742293
# RandomForestClassifier 50    0.759193
# RandomForestClassifier 80    0.751282
# Name: mean, dtype: float64

# %%
pl.clf()
ROCtrainTRN,ROCtestTRN,ROCtrainTRG,ROCtestTRG = cross_validation.train_test_split(train, 
                                                                                target, 
                                                                                test_size=0.25)

# %%
model = svm.SVC(kernel='linear', probability = True)
probas = model.fit(ROCtrainTRN, ROCtrainTRG).predict_proba(ROCtestTRN)
fpr, tpr, thresholds = roc_curve(ROCtestTRG, probas[:, 1])
roc_auc  = auc(fpr, tpr)
pl.plot(fpr, tpr, label='%s ROC curve (area = %0.2f)' % ('SVM_Liner',roc_auc))

model = RandomForestClassifier(n_estimators = 80, max_features='log2')
probas = model.fit(ROCtrainTRN, ROCtrainTRG).predict_proba(ROCtestTRN)
fpr, tpr, thresholds = roc_curve(ROCtestTRG, probas[:, 1])
roc_auc  = auc(fpr, tpr)
pl.plot(fpr, tpr, label='%s ROC curve (area = %0.2f)' % ('RandomForest 80',roc_auc))

pl.plot([0, 1], [0, 1], 'k--')
pl.xlim([0.0, 1.0])
pl.ylim([0.0, 1.0])
pl.xlabel('False Positive Rate')
pl.ylabel('True Positive Rate')
pl.legend(loc="lower right")
pl.show()
