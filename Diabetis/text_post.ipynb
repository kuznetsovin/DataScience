# %%
from pandas import read_csv, DataFrame
from sklearn import cross_validation, svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc
from pandas.tools.plotting import scatter_matrix
import pylab as pl, math



data = read_csv('DataScience/Diabetis/train.csv', header=None)

target = data[0]
train = data.drop(0, axis=1)

# %%
data.hist(figsize=(12,10))
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x1054cd350>,
#         <matplotlib.axes.AxesSubplot object at 0x1080d7f10>,
#         <matplotlib.axes.AxesSubplot object at 0x1080f6f10>],
#        [<matplotlib.axes.AxesSubplot object at 0x1081141d0>,
#         <matplotlib.axes.AxesSubplot object at 0x108133450>,
#         <matplotlib.axes.AxesSubplot object at 0x108316790>],
#        [<matplotlib.axes.AxesSubplot object at 0x1083305d0>,
#         <matplotlib.axes.AxesSubplot object at 0x10824eb90>,
#         <matplotlib.axes.AxesSubplot object at 0x10826fe50>]], dtype=object)

# %%
data[(data[2] < -3*math.sqrt(data[2].var())) | (data[6] < -3*math.sqrt(data[6].var()))]
# Out:
#      0         1         2         3         4         5         6         7  \
# 13  -1 -1.141108 -0.841174 -3.570271 -1.287373 -0.692439 -4.057829 -0.651547
# 29  -1 -1.141108 -0.590960  0.304536  0.154433 -0.692439 -4.057829  0.302189
# 52  -1 -1.141108 -0.090532 -0.263769  0.154433  0.079835 -4.057829  3.800226
# 111 -1 -0.844335 -3.781190 -1.090395 -0.033629 -0.692439 -0.924966 -1.001653
# 112 -1 -0.844335 -3.781190 -0.057113  0.906679 -0.692439  0.000941 -0.250133
# 113 -1 -0.844335 -3.781190  0.252871 -0.033629 -0.492863 -0.544456 -0.521767
# 250 -1 -0.547562 -1.466709 -3.570271 -1.287373 -0.692439 -4.057829 -1.116343
# 257 -1 -0.547562 -1.153942 -3.570271 -1.287373 -0.692439 -4.057829 -0.506676
# 353 -1 -0.250789 -1.279049 -3.570271 -1.287373 -0.692439 -4.057829 -0.899036
# 492  1  0.342757 -3.781190  0.562856  0.718617 -0.692439  1.142471 -0.379914
# 531 -1  0.342757  0.472450  0.666184 -1.287373 -0.692439 -4.057829  0.507423
# 549  1  0.639530 -3.781190 -0.057113  1.282802 -0.692439  0.888797  0.770002
# 572 -1  0.639530 -0.215639 -3.570271 -1.287373 -0.692439 -4.057829 -0.853764
# 607 -1  0.936304 -0.497129 -3.570271 -1.287373 -0.692439 -4.057829 -0.503658
# 664  1  1.233077  0.128406  1.389481 -1.287373 -0.692439 -4.057829 -0.723983
# 719  1  1.826623 -0.184362 -3.570271 -1.287373 -0.692439 -4.057829 -0.636457
#
#             8
# 13  -0.700742
# 29  -1.040871
# 52  -1.040871
# 111 -0.955839
# 112 -0.955839
# 113 -1.040871
# 250 -0.955839
# 257 -1.040871
# 353 -0.955839
# 492  0.319646
# 531  3.040681
# 549  0.659776
# 572 -0.615709
# 607 -0.785774
# 664  1.765196
# 719 -0.275580

# %%
kfold = 10
itog = DataFrame(index=xrange(kfold))

# %%
model = svm.SVC(kernel='linear')
scores = cross_validation.cross_val_score(model, train, target, cv = kfold)
itog.insert(len(itog.columns),'SVM Liner',scores)

# %%
model = svm.SVC(kernel='poly')
scores = cross_validation.cross_val_score(model, train, target, cv = kfold)
itog.insert(len(itog.columns),'SVM Poly',scores)

# %%
model = svm.SVC(kernel='rbf', gamma=0.7)
scores = cross_validation.cross_val_score(model, train, target, cv = kfold)
itog.insert(len(itog.columns),'SVM rbf',scores)

# %%
for n in range(5,15,4):   
    model = KNeighborsClassifier(n_neighbors = n)
    scores = cross_validation.cross_val_score(model, train, target, cv = kfold)
    FieldName = str(model)[:str(model).find('(')] + ' ' + str(model.n_neighbors)
    itog.insert(len(itog.columns), FieldName, scores)

# %%
model = BernoulliNB()
scores = cross_validation.cross_val_score(model, train, target, cv = kfold)
itog.insert(len(itog.columns),'BernulNaiveBaes',scores)

# %%
for n in range(20,81,30):
    model = RandomForestClassifier(n_estimators = n, max_features='log2')
    scores = cross_validation.cross_val_score(model, train, target, cv = kfold)
    FieldName = str(model)[:str(model).find('(')] + ' ' + str(model.n_estimators)
    itog.insert(len(itog.columns), FieldName, scores)

# %%
SumInfo = itog.describe().transpose()

# %%
SumInfo['mean'].plot(kind='bar', legend=False)

# %%
mdl =[]
mdl_avg_score = DataFrame(SumInfo['mean'])
for name_mdl in mdl_avg_score.index.to_series().str.split(' ', n=0).tolist():
    mdl.append(str(name_mdl[0]))
for name_mdl in set(mdl):
    mdl_avg_score.insert(len(mdl_avg_score.columns), name_mdl, 0.0)
    mdl_avg_score[name_mdl][mdl_avg_score.index.to_series().str.contains(name_mdl)] = mdl_avg_score['mean']
mdl_avg_score.drop('mean',axis=1).plot(kind='bar', stacked=True, align='center', figsize=(8,4))
plt.legend(loc=4, fontsize='medium',bbox_to_anchor = (1.4, 0.7))

# %%
SumInfo['mean']
# Out:
# SVM Liner                    0.769532
# SVM Poly                     0.743455
# SVM rbf                      0.739645
# KNeighborsClassifier 5       0.746292
# KNeighborsClassifier 9       0.742293
# KNeighborsClassifier 13      0.743524
# BernulNaiveBaes              0.722710
# RandomForestClassifier 20    0.752614
# RandomForestClassifier 50    0.746172
# RandomForestClassifier 80    0.760424
# Name: mean, dtype: float64

# %%
ROCtrainTRN,ROCtestTRN,ROCtrainTRG,ROCtestTRG = cross_validation.train_test_split(train, 
                                                                                target, 
                                                                                test_size=0.25)

# %%
model = svm.SVC(kernel='linear', probability = True)
probas = model.fit(ROCtrainTRN, ROCtrainTRG).predict_proba(ROCtestTRN)
fpr, tpr, thresholds = roc_curve(ROCtestTRG, probas[:, 1])
roc_auc  = auc(fpr, tpr)
pl.clf()
pl.plot(fpr, tpr, label='%s ROC curve (area = %0.2f)' % ('SVM_Liner',roc_auc))

model = RandomForestClassifier(n_estimators = 80, max_features='log2')
probas = model.fit(ROCtrainTRN, ROCtrainTRG).predict_proba(ROCtestTRN)
fpr, tpr, thresholds = roc_curve(ROCtestTRG, probas[:, 1])
roc_auc  = auc(fpr, tpr)
pl.plot(fpr, tpr, label='%s ROC curve (area = %0.2f)' % ('RandomForest 80',roc_auc))

pl.plot([0, 1], [0, 1], 'k--')
pl.xlim([0.0, 1.0])
pl.ylim([0.0, 1.0])
pl.xlabel('False Positive Rate')
pl.ylabel('True Positive Rate')
pl.legend(loc="lower right")
pl.show()
